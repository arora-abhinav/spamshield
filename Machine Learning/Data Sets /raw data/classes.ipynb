# %%
import json

with open("final.csv", "a") as final:
    [
  "Your Amazon package has been delivered to the leasing office. Please collect it at your convenience.",
  "Your Zomato order has been picked up by the delivery partner and will arrive in 12 minutes.",
  "FedEx tracking update: Your shipment from Order #482910 has left the local facility.",
  "Swiggy: Your food order from Bistro Central is delayed by 10 minutes due to heavy traffic. We apologize.",
  "UPS Alert: Package 1Z999AA10123456784 was left on the front porch per your instructions.",
  "Your Blinkit order is packed and the rider is assigning shortly. Track live in the app.",
  "Instamart: Your groceries are at your doorstep. Thank you for shopping with us!",
  "Your DHL shipment is scheduled for delivery today between 2:00 PM and 5:00 PM. No signature required.",
  "Zomato delivery partner Rahul is 2 minutes away from your location. Please be ready to receive your meal.",
  "Your Amazon order containing 3 items has been handed directly to a resident.",
  "Swiggy Genie has picked up your documents from the pickup point. Total distance: 4.2 km.",
  "Your Zepto order has been delivered successfully. Rate your experience in the application.",
  "UPS Update: Your package is out for delivery today. It will be left by the mailbox if no one answers.",
  "FedEx: Shipment delivered at 11:42 AM. Signed for by: Front Desk.",
  "Your Myntra exchange request has been processed. The delivery agent will arrive tomorrow for the pickup.",
  "Your Blue Dart shipment tracking number 849201394 is arriving today. Have a great day.",
  "Your Domino's pizza is out of the oven and heading your way with our delivery expert.",
  "Amazon: Your subscription item has been shipped and will arrive by Thursday evening.",
  "Swiggy: Your order from Chai Point has been delivered. Enjoy your hot beverages!",
  "Your Urban Company professional has completed the service. The final invoice has been generated.",
  "Zomato: The delivery partner is currently outside your building gate. Please coordinate.",
  "Your Dunzo delivery executive has reached the drop location. Please check your door.",
  "Your Flipkart package is out for delivery today with our partner Ekart. Expected by 8 PM.",
  "UPS: Package was successfully delivered at the side door at 3:15 PM.",
  "Your BigBasket order slot for 6:00 AM - 8:30 AM tomorrow is confirmed. Our executive will call before arrival.",
  "Your Pizza Hut order has been dispatched. Track your rider's live location on our mobile platform.",
  "FedEx Notice: Delivery was successful. The package is located in the parcel locker facility.",
  "Amazon Alert: Your order #403-9182736-1928374 has been dispatched via our logistics network.",
  "Your Tata 1mg prescription order has been delivered. Please store medicines as instructed.",
  "Zomato: Your order from Absolute Barbecues has been delivered. We value your feedback.",
  "Your Swiggy order is arriving now. Please meet the delivery executive at the main entrance.",
  "Your DHL package is now out for delivery. Estimated delivery window is within the next three hours.",
  "Amazon Home Services: Your technician is on the way and should arrive within 20 minutes.",
  "Your package from Ajio has been sorted at the local hub and will be delivered tomorrow.",
  "Swiggy Instamart: Order confirmed. A delivery partner is heading to the store to pick up your items.",
  "Your FedEx package from Global Traders is delayed by one business day due to weather conditions.",
  "Zomato: Food is being prepared by the restaurant kitchen. Estimated delivery time is 35 minutes.",
  "Your Nike order has been shipped. Track your delivery status anytime using your registered account profile.",
  "UPS Update: Your shipment has arrived at the destination sorting facility in your city.",
  "Your order from Nykaa has been successfully delivered to your residential address.",
  "Your Licious meat order has been delivered in our specialized cold-chain packaging.",
  "Swiggy: The rider has reached the restaurant and is waiting for your food package.",
  "Amazon: Package left in the building lobby mailroom as per standard delivery preferences.",
  "Your grocery order from JioMart is out for delivery today with our executive.",
  "FedEx: Your package is available for pickup at the designated FedEx OnSite location.",
  "Zomato: Your order from Sweet Truth is arriving early. Expected arrival in 4 minutes.",
  "Your Delhivery package from merchant code 4829 is out for delivery in your zone today.",
  "UPS Alert: A delivery attempt was made, but a signature was required. We will retry tomorrow.",
  "Your Swiggy Gourmet order has been safely delivered by our premium partner.",
  "Amazon Prime: Your order will be delivered today by 9 PM. Track progress in your app.",
  "Your Uber Eats driver is arriving now with your lunch order. Please meet them outside.",
  "Your Dunzo order from the local pharmacy has been completed. Check your email for the bill.",
  "Blue Dart: Shipment #92018374 has been safely delivered to the security guard cabin.",
  "Your Zomato order has been accepted by the kitchen. Preparation is underway.",
  "Swiggy: Your order from Burger King has been delivered. Enjoy your meal!",
  "Your package from Apple has been shipped via courier and is scheduled for morning delivery.",
  "FedEx tracking: Shipment is currently in transit at the regional hub facility.",
  "Your Amazon Fresh grocery delivery window has started. The driver is on their way.",
  "UPS Notice: Your package from Nordstrom is arriving today before the end of the day.",
  "Your Swiggy Instamart items have been dropped off at your gate as requested.",
  "Zomato: Your delivery partner has picked up the food order from the restaurant.",
  "Your order from H&M has been dispatched from our warehouse and tracking is now active.",
  "DHL Express: Your shipment from international customs has been cleared and is moving forward.",
  "Your Milkbasket delivery for tomorrow morning has been processed based on your wallet balance.",
  "Amazon: Your package was handed to a family member at the residence.",
  "Swiggy: The delivery executive is near your location. Please check your phone for calls.",
  "Zomato: Your order from Subway is ready and the delivery partner is departing now.",
  "Your package from Decathlon has been dispatched via Blue Dart courier services.",
  "UPS: Package delivered to the residential garage area as per consumer preference options.",
  "Your country delight milk delivery has been completed for today's early morning slot.",
  "FedEx Update: Shipment delayed at the border facility due to standard paperwork processing.",
  "Amazon: Your delivery is 5 stops away. You can view the map in your active orders section.",
  "Your order from BookMyShow for the physical movie tickets has been dispatched via courier.",
  "Swiggy: Your order from Keventers has been safely delivered to your doorstep.",
  "Zomato: Driver is arriving in 1 minute. Please ensure you are available to collect.",
  "Your package from Sephora has been successfully delivered to your mailbox destination.",
  "UPS: Your delivery scheduled for today has been rescheduled to tomorrow due to operational issues.",
  "Your shadowfax delivery executive is out with your e-commerce package today.",
  "Swiggy Instamart: The delivery partner has arrived at your building entrance gate.",
  "Your Amazon order from seller Cloudtail has been shipped and tracking information is live.",
  "Zomato: Your dinner order has been successfully delivered. Thank you for using our platform.",
  "FedEx Notice: Package delivered at the front reception counter of your office building.",
  "Your PharmEasy medicine refill has been dispatched and will arrive this afternoon.",
  "UPS: Your package is on its way to the local service center for final sorting.",
  "Your Swiggy order has been assigned to a new delivery partner due to logistics rebalancing.",
  "Zomato: The restaurant has confirmed your order. Food preparation will begin immediately.",
  "Your grocery basket from BB Daily has been left in your designated delivery box.",
  "Amazon: Package delivered. Photos of the delivery location are available on your account page.",
  "Your shipment from Puma has been handed over to Delhivery for final transportation.",
  "FedEx: Your scheduled pickup has been completed successfully by our courier agent.",
  "Swiggy: Your delivery partner is waiting at the restaurant for your order preparation.",
  "Your Zomato food delivery from Paradise Biryani is now arriving at your home.",
  "UPS: Your package from Best Buy has been delivered to the front porch area.",
  "Your Ajio order has been successfully delivered. For returns, please use the application.",
  "Amazon: Your package is arriving early today. Expected arrival between 1 PM and 3 PM.",
  "Your Swiggy order from Wow! Momo has been delivered. Have a wonderful meal experience.",
  "Zomato: Your rider is encountering rain and your delivery may take 15 additional minutes.",
  "Your shipment from Croma electronics has been dispatched with our delivery team.",
  "FedEx tracking update: Shipment has departed the origin facility in San Jose.",
  "Your Zepto delivery is at your door. Our rider followed your no-contact delivery instruction.",
  "UPS Alert: The delivery address provided is incomplete. Please update it via our tracking portal.",
  "Your Swiggy Instamart order has been delivered. Thank you for choosing fast grocery delivery.",
  "Zomato: Order #9283 from Haldiram's is arriving now with your delivery executive.",
  "Your Amazon order containing household essentials has been shipped via India Post.",
  "Your order from Urban Ladder furniture has been loaded onto the delivery truck today.",
  "FedEx: Delivered to the back porch area as requested by the homeowner.",
  "Swiggy: The restaurant is preparing your food with extra care. Arriving in 25 minutes.",
  "Your Zomato order has been dropped off at the security desk as per your profile settings.",
  "Your package from Lenovo has been cleared through customs and transferred to local courier networks.",
  "UPS: Package is currently out for delivery on route 412 in your neighborhood.",
  "Your order from LensKart has been processed and shipped via Blue Dart tracking.",
  "Swiggy Instamart: Your order containing dairy products has been successfully delivered.",
  "Zomato: Your delivery partner has reached the designated drop-off coordinates.",
  "Your Amazon package has been picked up from the local hub and will arrive today.",
  "FedEx Notice: Your shipment requires an adult signature upon delivery tomorrow morning.",
  "Your order from FirstCry has been packed and is ready for shipment collection.",
  "Swiggy: The delivery partner has picked up your dessert order from The Baking Company.",
  "Your Zomato order from McDonald's is on its way and will arrive shortly.",
  "UPS: Shipment delivered at the main entrance desk of the commercial property.",
  "Your package from Max Fashion has been delivered to your primary residential address.",
  "Amazon: Your delivery driver has completed their route and your package is at your door.",
  "Swiggy: Your food order from Mainland China is arriving in approximately 5 minutes.",
  "Zomato: Order has been successfully delivered by our partner. Enjoy your food!",
  "Your DHL parcel from European Retailers has arrived at the local processing center.",
  "FedEx: Your package is out for delivery today between the hours of 9 AM and 6 PM.",
  "Your grocery bundle from Nature's Basket has been shipped and is en route.",
  "Swiggy Instamart: A delivery executive has been assigned to your late-night order.",
  "Your Zomato order from Starbucks is being prepared by the barista now.",
  "UPS Update: Your package has been delayed due to mechanical issues with the transport vehicle.",
  "Amazon: Your package is 2 stops away. Please ensure access to your property is clear.",
  "Your shipment from Reliance Digital has been delivered and verified by our agent.",
  "Swiggy: Your lunch order has been delivered to your specified office floor desk.",
  "Zomato: The delivery partner is at the restaurant counter waiting for packaging to complete.",
  "Your package from Bewakoof apparel has been handed over to Ecom Express courier.",
  "FedEx: Shipment delivered successfully to the residential side gate entrance.",
  "Your order from Apollo Pharmacy has been delivered by the local store executive.",
  "UPS: Your package is currently on the delivery vehicle and moving toward your location.",
  "Swiggy: Your order from Dunkin' Donuts has been delivered to your house.",
  "Zomato: Your order from PVR Cafes has been canceled because the restaurant is closed.",
  "Your Amazon package has been placed inside your secure parcel drop box outside.",
  "Your order from Westside has been packed and labeled for immediate logistics pickup.",
  "FedEx Tracking: Your package has arrived at the country destination hub facility.",
  "Swiggy Instamart: Your order is on the way with our rider. Estimated arrival: 8 minutes.",
  "Your Zomato order from Copper Chimney has been picked up by the delivery executive.",
  "Your delivery from Pepperfry furniture is scheduled for arrival this afternoon between 3 and 6 PM.",
  "UPS Notice: Your package was delivered to a neighbor at address number 42.",
  "Amazon: Your order #102-93847-10293 has been delivered to your front entryway.",
  "Your Swiggy order from Baskin Robbins is packaged in insulated bags and en route.",
  "Zomato: Your order has been delivered. Please rate your delivery executive inside the app.",
  "Your flight AI-402 from Delhi to Mumbai is delayed by 45 minutes. New departure time is 6:15 PM.",
  "IndiGo Alert: Boarding for flight 6E-2105 to Bangalore has commenced at Gate number 4.",
  "Your train 12626 Kerala Express is running 20 minutes behind schedule. Expected arrival at 4:10 PM.",
  "Uber confirmation: Your driver is arriving in 3 minutes in a white Maruti Suzuki Desire.",
  "Your bus from Boston to New York is delayed by 15 minutes due to traffic on I-95.",
  "Dad reached the airport safely and is currently checking in his bags for the flight.",
  "SpiceJet update: Flight SG-342 from Kolkata is now arriving at Terminal 2 instead of Terminal 1.",
  "Your Ola cab has arrived at your pickup point. The driver will wait for 5 minutes.",
  "Your flight UA-1084 from Chicago to Denver is on time. Gate closes 15 minutes prior to departure.",
  "The metro train service on the Blue Line is temporarily delayed due to a technical glitch.",
  "Your bus ticket for the 9:30 PM departure from Pune to Mumbai has been confirmed. Seat 12B.",
  "Flight check-in reminder: Online check-in for your flight LH-756 to Frankfurt is now open.",
  "Your train 12002 Bhopal Shatabdi has departed New Delhi on time. Have a safe journey.",
  "Delta Air Lines: Flight DL-482 has landed safely at Atlanta Hartsfield-Jackson Airport.",
  "Your rapid transit shuttle is arriving in 5 minutes at stop 14 outside the main terminal.",
  "Mom's flight has just taken off from Dubai. Expected arrival time in Mumbai is 4:30 AM.",
  "Air India Update: Flight AI-101 to New York JFK has been rescheduled to 2:30 AM tomorrow.",
  "Your Rapido captain has reached your pickup location. Please share the start pin.",
  "The international ferry from Dover to Calais is delayed by 30 minutes due to sea conditions.",
  "Your train ticket status has been upgraded from WL 4 to Confirmed. Coach B1, Seat 42.",
  "Vistara flight UK-812 from Mumbai to Delhi is now boarding at Gate 12A. Please proceed.",
  "Your Uber ride is complete. A receipt for your journey has been sent to your email address.",
  "The commuter rail to downtown is operating on a modified schedule today due to track maintenance.",
  "Your flight AA-2405 from Dallas to Los Angeles is delayed by 1 hour due to air traffic control.",
  "We have arrived safely at the hotel in Jaipur. The road trip went smoothly with no delays.",
  "IndiGo flight 6E-504 from Chennai to Hyderabad has landed. Welcome to your destination.",
  "Your NMMT bus route 123 is arriving at your current stop in approximately 7 minutes.",
  "Train 12952 Mumbai Rajdhani is currently crossing Ratlam station, running on schedule.",
  "Your shuttle bus from the parking lot to the main concert venue is departing now.",
  "Your flight to Singapore SQ-421 is delayed by 50 minutes. Please check screens for updates.",
  "Ola Alert: Your driver had to cancel the ride. We are assigning a new cab immediately.",
  "The cross-country bus has entered the intermediate station for a 15-minute rest stop.",
  "Flight reassurance: Your connection in London Heathrow is on schedule. Gate info to follow.",
  "Just passed the highway toll plaza. We should reach your house in about 30 minutes.",
  "Akasa Air flight QP-1102 from Bengaluru to Kochi has completed boarding. Doors are closed.",
  "Your train 22416 New Delhi Varanasi Vande Bharat is arriving on platform number 1 shortly.",
  "Your Uber driver is stationary due to traffic but is still moving toward your location.",
  "The morning ferry service across the bay has been suspended today due to dense fog.",
  "Your flight JetBlue B6-402 to Boston is on time. Baggage drop is available at counter 5.",
  "Landed safely in Tokyo. Going through immigration now. Will call you once I get my bags.",
  "Air India flight AI-805 from Delhi to Bengaluru is delayed by 2 hours due to bad weather.",
  "Your reservation on the 4:15 PM express coach to Seattle has been successfully checked in.",
  "Train 12260 Duronto Express is running late by 1 hour and 30 minutes. Revised time updated.",
  "Your Ola Auto is 1 minute away. Please ensure you are at the designated gate entry.",
  "Flight update: Southwest WN-849 departure gate has been changed from Gate B4 to Gate B12.",
  "The school bus has left the campus and is on its normal afternoon drop-off route.",
  "British Airways: Your flight BA-143 to London is on time. Estimated flight time is 9 hours.",
  "Your regional train service has been diverted via the loop line, adding 10 minutes to the trip.",
  "Uber is arriving now. The vehicle is a silver Hyundai i20. Please verify the license plate.",
  "Landed in Chennai. The weather is warm here. Waiting at the baggage carousel for my luggage.",
  "IndiGo flight 6E-902 from Goa to Mumbai is delayed by 35 minutes. New departure is 11:15 PM.",
  "Your train 12010 Ahmedabad Mumbai Shatabdi is scheduled to arrive on platform 5 today.",
  "Your airport shuttle van is currently 3 kilometers away from your residential pickup point.",
  "Flight delay: Emirates EK-506 from Dubai to Mumbai is delayed by 40 minutes due to late arrival.",
  "The interstate bus has crossed the state border. Expected arrival at the terminal is 6 AM.",
  "We are boarding the train now. Our seats are in the middle of the coach. Talk to you later.",
  "SpiceJet SG-213 from Delhi to Srinagar is on time. Boarding begins in 20 minutes at Gate 5.",
  "Your Uber ride request has been accepted. Your driver is currently finishing another trip nearby.",
  "The commuter ferry is arriving at the pier in 3 minutes. Please stand behind the yellow line.",
  "Flight change: Your flight from Paris CDG has been assigned a new departure time of 2:15 PM.",
  "Train 12625 Grand Trunk Express is running on time and will arrive at Bhopal station shortly.",
  "Ola: Your ride OTP is 4920. Share this with your driver only after entering the vehicle.",
  "The tour bus is departing from the museum entrance in 10 minutes. Please return to your seats.",
  "Landed in Frankfurt safely. The flight was comfortable. Catching my connecting flight now.",
  "Vistara flight UK-945 from Delhi to Mumbai has landed safely. Thank you for flying with us.",
  "Your train 12424 New Delhi Dibrugarh Rajdhani is operating on schedule today.",
  "Your Uber driver is arriving. Please meet them at the designated rideshare pickup zone.",
  "The city express bus service is experiencing 15-minute delays across all central routes.",
  "Flight update: Delta DL-1042 from New York to Miami is on time. Pre-boarding has started.",
  "We have arrived at the railway station. Waiting on platform 3 for the train to arrive.",
  "Air India flight AI-302 to Sydney is delayed by 45 minutes due to operational reasons.",
  "Your bike taxi rider from Rapido is 2 minutes away from your specified corporate gate.",
  "The mountain railway toy train is running 10 minutes late due to track clearing activities.",
  "Flight confirmation: Your seat assignment for flight AA-482 to Chicago has been updated to 14C.",
  "Landed safely in San Francisco. The immigration line is quite long. Will update soon.",
  "IndiGo 6E-2415 from Jaipur to Delhi is delayed by 30 minutes. We regret the inconvenience caused.",
  "Your train 12951 Mumbai Tejas Rajdhani has successfully departed from Mumbai Central station.",
  "Your Ola cab driver is near the pickup point. Please look out for a red hatchback.",
  "The long-distance coach service to Edinburgh is on time. Boarding starts at platform 2.",
  "Flight alert: Lufthansa LH-757 from Frankfurt to Mumbai is delayed by 15 minutes.",
  "We crossed the mountains safely. The road conditions were good. Arriving in an hour.",
  "SpiceJet flight SG-405 from Pune to Delhi has completed landing procedures at Terminal 3.",
  "Your Uber driver has arrived at your location. High demand may cause longer waiting fees.",
  "The light rail service is currently suspended between the downtown and university stations.",
  "Flight check-in: Your mobile boarding pass for flight UA-402 is now ready in the app.",
  "Train 12009 Mumbai Ahmedabad Shatabdi is running 10 minutes early today. Expected arrival soon.",
  "Your car rental booking shuttle is departing from terminal gate 3 every 15 minutes.",
  "Landed in Dubai. The flight was delayed slightly but I will make my connection easily.",
  "Vistara flight UK-721 from Kolkata to Delhi is delayed by 25 minutes. Revised time is 8 PM.",
  "Your train 12801 Puri New Delhi Purushottam Express is currently arriving at Kanpur Central.",
  "Your Ola ride has been completed successfully. Your total fare amount is being processed.",
  "The regional bus service from the terminal to the village is running on its normal schedule.",
  "Flight delay notice: Air France AF-226 to Paris is delayed by 1 hour due to technical checks.",
  "Dad has reached his destination city safely. He will call you from the apartment shortly.",
  "IndiGo flight 6E-105 from Delhi to Goa is on time. Gate number 14 is open for boarding.",
  "Your train ticket booking under PNR 4829103948 has been successfully confirmed for travel.",
  "Your Uber driver is arriving in 4 minutes. The vehicle details are shown on your screen.",
  "The night express train is delayed by 20 minutes due to signal optimization on the route.",
  "Flight update: Singapore Airlines SQ-422 is on time. Boarding begins at Gate B6 in 30 minutes.",
  "Landed safely in Bangalore. The flight was smooth. Heading to the taxi stand now.",
  "SpiceJet SG-482 from Hyderabad to Delhi is delayed by 40 minutes. Revised departure at 4:50 PM.",
  "Your train 22691 Bangalore New Delhi Rajdhani is running on time, passing through Jhansi.",
  "Your Ola driver has reached the location. Please proceed to the vehicle within 5 minutes.",
  "The cross-bay ferry is running on schedule today. Next departure is at 2:00 PM sharp.",
  "Flight alert: Qatar Airways QR-572 from Doha to Bengaluru is delayed by 30 minutes.",
  "We arrived safely at the farmhouse. The traffic out of the city was lighter than expected.",
  "Air India AI-415 from Mumbai to Delhi has landed. Baggage can be collected at carousel 3.",
  "Your Uber package delivery vehicle has started moving toward your designated drop address.",
  "The high-speed rail line is experiencing minor delays of 5 minutes due to speed restrictions.",
  "Flight confirmation: Your flight from London to Boston is confirmed on flight BA-213.",
  "Landed in New York. The entry process was quick. Waiting for my luggage at the terminal.",
  "IndiGo flight 6E-824 from Ahmedabad to Delhi is delayed by 15 minutes. Boarding soon.",
  "Your train 12301 Howrah Rajdhani Express is scheduled to arrive on platform number 8.",
  "Your Ola cab is arriving now. Please check the driver name matches your application record.",
  "Your OTP for phone number verification is 847291. Do not share this with anyone. Valid for 10 minutes.",
  "Bank OTP: 334821 is your one-time password for the transaction of USD 45.00. Expires in 5 minutes.",
  "Use 910384 to log in to your Amazon account. Do not share this code with anyone for safety.",
  "Your Netflix verification code is 482019. It will expire shortly. Do not disclose this password.",
  "Your one-time password for HDFC Bank NetBanking is 554930. Bank staff will never ask for this.",
  "Verification code: 284013. Enter this to complete your Google account registration process.",
  "Your OTP for changing your Apple ID password is 839201. Do not share it with third parties.",
  "ICICI Bank: OTP for your online transaction is 109483. Valid for 3 minutes. Keep it confidential.",
  "Use code 472910 to verify your Uber phone number. Never share your OTP with anyone, including drivers.",
  "Your Microsoft security code is 384910. If you did not request this, please ignore this message.",
  "Your Zomato login OTP is 8492. It is valid for 2 minutes and should not be shared.",
  "SBI OTP: 774839 is your code for online shopping. Do not disclose this to anyone for security.",
  "Use OTP 392014 to authorize your login on the LinkedIn platform. Valid for exactly 5 minutes.",
  "Your Swiggy verification code is 2940. Enter this code to complete your profile verification.",
  "Your one-time authorization code is 810492 for accessing your PayPal dashboard wallet.",
  "Axis Bank: Your transaction OTP is 948201. Please do not share this code with anyone.",
  "Your WhatsApp verification code is 382-910. Do not share this sequence with other users.",
  "Use code 849302 to complete your login process on the Spotify application interface.",
  "Your OTP for the transaction at merchant code 4829 is 104938. Valid for 10 minutes only.",
  "Your Instagram login confirmation code is 839201. Do not share this under any circumstances.",
  "Your OTP for processing your tax return login is 773910. Keep this code confidential.",
  "Kotak Bank OTP: 294018 for your debit card purchase. Valid for three minutes from generation.",
  "Use 849201 to verify your identity on the Zoom video conferencing platform application.",
  "Your OTP for resetting your Adobe account password is 910384. Do not disclose to anyone.",
  "Your verification code for Discord is 482910. This code expires in exactly 10 minutes.",
  "Chase Alert: Use OTP 339481 to authorize your web portal login session. Stay secure.",
  "Your login OTP for Flipkart is 938421. It is valid for five minutes. Do not share.",
  "Your one-time security code for PlayStation Network is 849201. Keep it safe.",
  "Use code 104938 to authorize your connection to the corporate VPN network portal.",
  "Punjab National Bank: Your internet banking login OTP is 884739. Do not share.",
  "Your verification code for Twitter/X is 938201. Valid for ten minutes from issuance.",
  "Your Myntra login OTP is 5839. Enter this to access your shopping account profile.",
  "Your authentication code for the GitHub repository access is 849302. Keep it confidential.",
  "Bank of America: Your one-time verification passcode is 294018. Expires in 5 minutes.",
  "Use code 748392 to verify your registration on the Reddit online community platform.",
  "Your OTP for activating your digital health card is 104928. Do not share with anyone.",
  "Your login authorization code for the Slack workplace application is 839201.",
  "Canara Bank: OTP for your retail banking transfer is 994832. Valid for 3 minutes.",
  "Your verification code for Airbnb is 482910. Do not share this with your host.",
  "Use OTP 839401 to complete your flight booking confirmation on the travel portal.",
  "Your authentication code for Steam is 910284. Enter this inside the desktop client.",
  "Your login OTP for Dunzo is 8492. It will expire in exactly two minutes.",
  "Union Bank: Your secure transaction OTP code is 748392. Do not disclose to staff.",
  "Your verification code for the Telegram messaging app is 938-401. Keep it private.",
  "Use code 849302 to finalize your delivery address update on the e-commerce store.",
  "Your one-time token for accessing your cloud storage account is 104938. Valid for 5 min.",
  "Standard Chartered: Your online purchase OTP is 883920. Do not share this code.",
  "Your login confirmation code for Pinterest is 938421. Expires in ten minutes.",
  "Your verification code for Twitch is 849201. Enter this to start your stream session.",
  "Use OTP 104928 to authorize the linking of your mobile number to your loyalty profile.",
  "IDFC First Bank: Your login verification OTP is 748392. Keep it strictly confidential.",
  "Your authentication code for the Oracle cloud infrastructure is 839201. Do not share.",
  "Your verification code for the Uber Eats application platform is 482910.",
  "Use code 938402 to confirm your appointment booking on the healthcare portal system.",
  "Indian Bank: Your registered mobile banking transaction OTP is 849302. Expires soon.",
  "Your login verification code for the Canva design suite is 104938. Valid for 5 minutes.",
  "Your security code for Adobe Creative Cloud is 883920. Do not share with others.",
  "Use OTP 938421 to verify your email address migration process on the user console.",
  "Federal Bank: Your account verification OTP is 849201. Valid for exactly three minutes.",
  "Your authentication token for the Salesforce dashboard is 104928. Keep it confidential.",
  "Your login verification code for the Zepto application is 9482. Valid for 2 minutes.",
  "Use code 748392 to authorize the digital signature on your document archive portal.",
  "Yes Bank: Your secure online payment OTP code is 839201. Do not share with anyone.",
  "Your verification code for the eBay shopping platform is 482910. Expires shortly.",
  "Your login OTP for the Blinkit application is 8493. Do not disclose this to riders.",
  "Use code 104938 to verify your domain ownership inside the web hosting console.",
  "Citi Bank Notice: Your transaction authentication code is 883920. Keep it private.",
  "Your verification code for the Notion workspace app is 938421. Valid for 10 minutes.",
  "Your login authorization token for the Zoomcar rental app is 849201. Do not share.",
  "Use OTP 104928 to complete your entry into the online educational webinar session.",
  "RBL Bank: Your credit card transaction security code is 748392. Valid for 3 minutes.",
  "Your authentication code for the GitLab developer environment is 839201. Keep it safe.",
  "Your login verification code for the Tata 1mg app is 4829. Do not share.",
  "Use code 849302 to confirm your subscription preferences on the media stream platform.",
  "Bank of Baroda: Your net banking portal OTP is 104938. Do not share under any condition.",
  "Your verification code for the Bitbucket source platform is 883920. Valid for 5 min.",
  "Your login OTP for the Nykaa fashion store is 938421. Expires in five minutes.",
  "Use code 849201 to authorize the generation of your utility bill statement copy.",
  "IndusInd Bank: Your mobile app registration verification OTP is 104928. Do not share.",
  "Your authentication code for the Autodesk student portal is 748392. Keep it confidential.",
  "Your login verification code for the JioMart grocery portal is 8392. Valid for 2 mins.",
  "Use code 482910 to verify your profile deletion request on the forum website.",
  "Central Bank: Your secure financial transaction token is 849302. Expires in 3 minutes.",
  "Your verification code for the Booking.com travel application is 104938. Do not share.",
  "Your login OTP for the Apollo 247 medical app is 8839. Keep this code confidential.",
  "Use code 938421 to authorize your connection to the wireless guest network portal.",
  "HSBC Bank: Your online payment confirmation code is 849201. Valid for three minutes.",
  "Your authentication token for the Shopify vendor dashboard is 104928. Keep it secure.",
  "Your login verification code for the BigBasket app is 7483. Do not share with anyone.",
  "Use code 839201 to confirm your newsletter email registration process online.",
  "Professor moved the quiz from Tuesday to Thursday. Please check Canvas for the updated syllabus.",
  "Assignment 4 grading rubric is now posted on the class portal. Review it before submitting.",
  "The guest lecture venue has been changed to Room 214 in the Science Block. Time remains 2 PM.",
  "The mid-semester feedback form is open on the portal. Please complete it by Friday night.",
  "Lecture notes for Chapter 5 on Linear Regression have been uploaded to the shared drive folder.",
  "Reminder: The physics lab reports are due tomorrow morning at 9:00 AM sharp at the TA office.",
  "The office hours for Dr. Smith today are canceled due to an urgent department meeting.",
  "Please read the assigned paper on neural networks before tomorrow's seminar discussion class.",
  "The final exam schedule has been officially published on the university website notice board.",
  "Chemistry Lab group assignments have been updated. Check your email for your team details.",
  "The mathematics tutorial class for Section B will be held in the auditorium today instead.",
  "Your grade for Quiz 2 has been published. You can view your scorecard on the intranet portal.",
  "The deadline for the computer science project has been extended by 48 hours for all batches.",
  "Professor Davis will conduct an extra review session for the upcoming exam this Wednesday at 4 PM.",
  "Please bring a scientific calculator to the engineering mechanics class tomorrow morning.",
  "The anthropology workshop registration list is full. No more walk-ins will be accepted.",
  "The university library will remain closed this Sunday for scheduled electrical maintenance work.",
  "Your assignment submission has been successfully uploaded to the system turn-in portal.",
  "The biology lecture schedule for next week has been slightly adjusted. Review the calendar.",
  "Professor Martinez has uploaded the solution set for the mock exam on the course web portal.",
  "The seminar on quantum computing has been postponed to next Monday due to speaker availability.",
  "Please download the dataset for Lab 3 from the portal before coming to the computer center.",
  "The history department seminar has been moved from Hall A to the Humanities building Lounge.",
  "Reminder: The economics presentation slides must be emailed to the TA before midnight tonight.",
  "Dr. Jones will hold his office hours virtually today via the standard department video link.",
  "The venue for the statistics practical exam has been finalized as Lab 2 on the third floor.",
  "The reading material for the political science module is now available at the campus bookstore.",
  "Please check your student email for instructions regarding the upcoming field trip logistics.",
  "The sociology quiz results are under review and will be announced early next week.",
  "Professor Wilson's lecture today will start 15 minutes late. Please wait inside the classroom.",
  "The deadline for choosing your elective courses for the next semester is tomorrow at 5 PM.",
  "The project teams for the software engineering module have been locked by the course coordinator.",
  "Please review the corrections made to your lab journals and return them to the cabinet.",
  "The academic counseling session for freshman students will take place in the main hall at 11 AM.",
  "Dr. Taylor has updated the reading list for the literature course on the digital platform.",
  "The geology field notes template has been shared on the group drive. Please print a copy.",
  "Reminder: The research proposal draft must be submitted directly to the professor via email.",
  "The venue for the environmental science presentation is Room 105 in the West Campus block.",
  "The computer networks lecture for today is canceled. Please follow the self-study module.",
  "Your attendance percentage for the current month has been updated on the student dashboard.",
  "The registration link for the annual science symposium is now active on the college website.",
  "Professor Brown has extended his evening office hours to accommodate exam preparation queries.",
  "The syllabus for the architecture history exam has been finalized. No changes will be made.",
  "Please ensure your lab kits are complete before the practical examination session on Tuesday.",
  "The assignment 3 feedback has been individually emailed to all registered course students.",
  "The room number for the philosophy elective class has been permanently changed to Room 302.",
  "Dr. Clark's review session video recording has been uploaded to the digital library archive.",
  "The schedule for the final project viva presentations has been sent to your team leads.",
  "Please read chapters 7 and 8 of the textbook prior to the discussion session on Thursday.",
  "The university has announced a holiday tomorrow due to the regional administrative directive.",
  "The accounting workshop slides have been posted on the student resource portal section.",
  "The deadline for submitting the internship completion certificate is the end of this week.",
  "Professor White will be available for project consultations from 2 PM to 4 PM tomorrow.",
  "The venue for the linguistics seminar has been shifted to the conference hall in block 3.",
  "The mock test portal will remain open for practice until Saturday evening at 8:00 PM.",
  "Please collect your corrected mid-term answer sheets from the department office desk.",
  "The schedule for the remedial math classes has been posted on the main notice board.",
  "Dr. Adams has uploaded the revised project guidelines document to the learning platform.",
  "The introduction to psychology lecture will be held combined with Section C in Hall 2.",
  "Reminder: The enrollment fee payment deadline for the summer semester is fast approaching.",
  "The final rubric for the drama project evaluation has been published by the instructor.",
  "Please update your contact details on the university student information system portal.",
  "The mechanical engineering workshop session for batch B3 is rescheduled to Friday morning.",
  "Professor Garcia will accept late submissions for assignment 2 only with a valid medical note.",
  "The reference books for the advanced calculus module have been placed on reserve in the library.",
  "The venue for the upcoming career guidance seminar is the university convention center.",
  "The online portal for selecting your thesis advisor is now accessible for senior students.",
  "Please review the feedback on your thesis abstract and schedule a follow-up with your guide.",
  "The data science project presentation order has been determined by a random draw system.",
  "Dr. Thomas has canceled the morning lecture today. A makeup class will be announced later.",
  "The university sign-in credentials for the digital library have been updated for this term.",
  "The international relations quiz has been rescheduled to next Wednesday morning at 10 AM.",
  "Please submit your group choice for the marketing case study by the end of today's session.",
  "The room allocation for the biochemistry practical exam has been updated on the website.",
  "Professor Lee has shared the code repository link for the machine learning assignments.",
  "The deadline for submitting requests for course withdrawals is this Friday afternoon.",
  "The fine arts exhibition setup instructions have been sent to all participating students.",
  "Please check your dashboard for the allocated seating arrangement for the mid-term exams.",
  "The sociology department lecture today will be conducted by a visiting faculty member.",
  "Dr. Roberts has posted the answers to the homework problems on the notice board outside.",
  "Google sign-in alert: A new login was detected on a Windows device from New Delhi, India.",
  "Suspicious payment attempt blocked: Your bank stopped a charge of $120.00 at an online merchant.",
  "Your Netflix subscription will automatically renew tomorrow. The amount will be debited soon.",
  "Security Notification: Your Apple ID password was successfully changed from an authorized device.",
  "Your monthly credit card statement for account ending in 4829 is now available online.",
  "Account Activity: A new device has successfully logged into your Spotify Premium profile account.",
  "Your Amazon account email address was successfully updated. Please check your inbox for details.",
  "Payment Received: Your utility bill payment of $85.50 was successfully processed today.",
  "Microsoft Security: An unusual sign-in attempt was blocked from an unrecognized IP address range.",
  "Your Disney+ Hotstar subscription has been successfully renewed for the next annual cycle.",
  "Your bank account ending in 9102 was credited with your monthly salary transfer amount.",
  "Alert: Your Google Cloud trial period is ending in three days. Review your resource usage.",
  "Your LinkedIn password has been successfully updated per your recent security request.",
  "Payment Confirmed: Your insurance premium payment has been credited to your policy folder.",
  "Security Alert: Your Facebook account was accessed from an unrecognized browser in London, UK.",
  "Your Adobe Creative Cloud subscription renewal is scheduled for processing on June 1st.",
  "An automated backup of your WhatsApp chat history was successfully completed to iCloud storage.",
  "Bank Alert: Your debit card was used for a contactless payment at a local merchant terminal.",
  "Your Sony PlayStation Network account has been successfully linked to your Discord profile.",
  "Your annual web hosting plan with GoDaddy is set to renew automatically in 48 hours.",
  "Google Alert: Recovery phone number for your account was changed. Verify if this was you.",
  "Your automatic monthly payment to the gym membership has been processed successfully.",
  "Security Notice: A new API token was generated for your GitHub developer account workspace.",
  "Your Apple iCloud storage plan has been upgraded to 200GB following your confirmation.",
  "Bank Update: Your request for an address change on your savings account has been completed.",
  "Your YouTube Premium membership payment was successful. Enjoy uninterrupted ad-free viewing.",
  "Alert: A login attempt to your PayPal account from a new location was verified by your device.",
  "Your mobile postpaid bill has been generated and is due for payment by the 15th of this month.",
  "Security Update: Two-factor authentication has been successfully enabled on your Zoom account.",
  "Your Canva Pro subscription auto-renewal was completed. Thank you for your continued usage.",
  "Bank Alert: A new international transaction capability has been activated on your credit card.",
  "Google Security: Your account password was changed using a verified backup code protocol.",
  "Your Microsoft 365 family subscription renews tomorrow. The card on file will be charged.",
  "Your vehicle insurance policy document has been generated and uploaded to your digital vault.",
  "Account Alert: An unrecognized device was removed from your Netflix account sharing list.",
  "Your automatic toll wallet recharge was successful via your linked primary bank account.",
  "Security Notification: Your Twitter/X account email address was modified from the settings panel.",
  "Your Dropbox Plus account storage limit has reached 85%. Consider organizing your files.",
  "Bank Notice: Your fixed deposit account has reached its maturity date and funds are processed.",
  "Your Uber account profile picture was updated successfully through the mobile application.",
  "Google sign-in: Your account was accessed from a new Mac computer near San Francisco, CA.",
  "Your monthly newspaper subscription payment was successfully debited from your card wall.",
  "Security Alert: A login attempt to your Steam account was blocked due to incorrect credentials.",
  "Your LinkedIn Premium trial period has ended and your regular membership is now active.",
  "Bank Alert: Your daily ATM withdrawal limit has been successfully adjusted via net banking.",
  "Your Apple ID was used to sign in to a new Apple TV device in your home network.",
  "Payment confirmation: Your broadband internet service renewal payment has been received.",
  "Security Update: The recovery email address for your Microsoft account has been verified.",
  "Your Spotify account has been transitioned to the free tier following subscription end.",
  "Account Alert: Your cryptocurrency wallet app detected a login from a different IP address.",
  "Your domestic electricity bill payment has been successfully recorded by the utility board.",
  "Google Security: A privacy checkup is recommended for your account. No urgent action required.",
  "Your Zomato Gold membership has been successfully activated for the next quarter period.",
  "Bank Alert: Your credit card transaction at an automated fuel dispenser was approved.",
  "Security Notification: Your Instagram account password has been reset using your phone link.",
  "Your Notion Plus workspace subscription has been updated to the annual billing cycle plan.",
  "Your airline loyalty program miles balance has been updated following your recent travel flight.",
  "Account Update: Your residential address details were modified on your e-commerce profile.",
  "Google sign-in alert: Your profile was accessed on an Android device from Bengaluru, India.",
  "Your Apple storage plan payment was successful. Your backup systems are operating normally.",
  "Security Notice: An application was granted read-only access permission to your GitHub account.",
  "Your LinkedIn profile visibility settings were successfully updated to open to work status.",
  "Bank Alert: A check deposit of $500.00 has been cleared and credited to your account.",
  "Your Duolingo Plus subscription auto-renews tomorrow. The transaction is processing.",
  "Security Update: A new secondary phone number has been linked to your Amazon shopping account.",
  "Your monthly residential water bill payment has been confirmed by the municipal council.",
  "Account Activity: Your Zoom profile email address was updated via the administrative console.",
  "Google Security: Suspicious activity was analyzed, but the login was confirmed as authorized.",
  "Your Coursera specialization subscription payment has been successfully completed for this month.",
  "Bank Alert: A standing instruction for your monthly home loan payment was executed today.",
  "Your Microsoft account security info was updated. The standard 30-day waiting period started.",
  "Your PlayStation Plus membership renewal has been confirmed. The receipt is in your email.",
  "Account Notification: Your Slack account password was changed by the organization admin.",
  "Your local municipal property tax payment has been processed and the receipt is available.",
  "Google sign-in: Access detected from a Linux desktop terminal browser in Berlin, Germany.",
  "Your Adobe account profile information was successfully modified via the web portal interface.",
  "Bank Notice: A new supplementary debit card has been issued for your checking account folder.",
  "Your Scribd reading platform membership has been successfully renewed for another month.",
  "Security Alert: Your Pinterest account login location shifted significantly since last session.",
  "Your automatic mobile wallet top-up was completed using your saved payment credentials.",
  "Google Security Alert: App access permissions were revoked for an outdated third-party tool.",
  "Your NYT digital news subscription has renewed. Thank you for supporting modern journalism."
]
# Out:
# defaultdict(<class 'int'>, {'ham': 8555, 'spam': 3153})
